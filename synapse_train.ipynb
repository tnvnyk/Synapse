# %%
#!pip install torch torchvision torchaudio

# !pip install packaging
# !pip install timm==0.4.12
# !pip install pytest chardet yacs termcolor
# !pip install submitit tensorboardX

# %%
# !pip install ml_collections
# Out:
# Collecting ml_collections
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml_collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from ml_collections) (6.0.3)
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: ml_collections
# Successfully installed ml_collections-1.1.0

# %%
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install causal-conv1d==1.4.0 && pip install mamba-ssm==2.2.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/gpu_features/
# Out:
# /content/drive/.shortcut-targets-by-id/1FTGWdCLE0XRLzqrkRt55D9GnFIALowrJ/synapse_features

# %%
# %cd /content
# !git clone https://github.com/JCruan519/VM-UNet.git
# Out:
# /content
# Cloning into 'VM-UNet'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 108 (delta 32), reused 23 (delta 23), pack-reused 67 (from 1)
# Receiving objects: 100% (108/108), 53.48 KiB | 8.91 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# !git clone https://github.com/MzeroMiko/VMamba.git
# Out:
# Cloning into 'VMamba'...
# remote: Enumerating objects: 8910, done.
# remote: Counting objects: 100% (1398/1398), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 8910 (delta 1341), reused 1223 (delta 1223), pack-reused 7512 (from 2)
# Receiving objects: 100% (8910/8910), 34.84 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (5492/5492), done.

# %%
# %cd /content/VM-UNet/
# Out:
# /content/VM-UNet

# %%
# !pip install scikit-learn matplotlib thop h5py SimpleITK scikit-image medpy yacs

# %%
# %cd /content/VM-UNet/datasets
# !touch __init__.py
# Out:
# /content/VM-UNet/datasets

# %%
# !pip install ml_collections
# Out:
# Requirement already satisfied: ml_collections in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml_collections) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from ml_collections) (6.0.3)

# %%
# !python train_synapse.py
# Out:
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/selective_scan_interface.py:163: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/selective_scan_interface.py:239: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/triton/layer_norm.py:985: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/triton/layer_norm.py:1044: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/distributed/tensor_parallel.py:25: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/distributed/tensor_parallel.py:61: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/triton/ssd_combined.py:757: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# /usr/local/lib/python3.12/dist-packages/mamba_ssm/ops/triton/ssd_combined.py:835: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   @custom_bwd
# #----------Creating logger----------#
# #----------GPU init----------#
# #----------Preparing dataset----------#
# #----------Prepareing Models----------#
# #----------Prepareing loss, opt, sch and amp----------#
# #----------Set other params----------#
# #----------Resume Model and Other params----------#
# #----------Training----------#
# 251 301
# 251
# train: epoch 251, iter:0, loss: 0.1229, lr: 0.0005049999999999994
# Finish one epoch train: epoch 251, loss: 0.1205, time(s): 217.33
# 252
# train: epoch 252, iter:0, loss: 0.1144, lr: 0.000489451674256325
# Finish one epoch train: epoch 252, loss: 0.1124, time(s): 27.49
# 253
# train: epoch 253, iter:0, loss: 0.1588, lr: 0.00047391869283298856
# Finish one epoch train: epoch 253, loss: 0.1350, time(s): 29.10
# 254
# train: epoch 254, iter:0, loss: 0.0894, lr: 0.0004584163849073342
# Finish one epoch train: epoch 254, loss: 0.1150, time(s): 23.52
# 255
# train: epoch 255, iter:0, loss: 0.1537, lr: 0.00044296004938566824
# Finish one epoch train: epoch 255, loss: 0.1111, time(s): 29.58
# 256
# train: epoch 256, iter:0, loss: 0.1272, lr: 0.0004275649398050843
# Finish one epoch train: epoch 256, loss: 0.1132, time(s): 31.82
# 257
# train: epoch 257, iter:0, loss: 0.0943, lr: 0.000412246249280065
# Finish one epoch train: epoch 257, loss: 0.1098, time(s): 27.05
# 258
# train: epoch 258, iter:0, loss: 0.1902, lr: 0.0003970190955087103
# Finish one epoch train: epoch 258, loss: 0.1246, time(s): 28.89
# 259
# train: epoch 259, iter:0, loss: 0.1101, lr: 0.00038189850585339583
# Finish one epoch train: epoch 259, loss: 0.1154, time(s): 31.68
# 260
# train: epoch 260, iter:0, loss: 0.0946, lr: 0.0003668994025105806
# Finish one epoch train: epoch 260, loss: 0.1195, time(s): 27.73
# 261
# train: epoch 261, iter:0, loss: 0.1111, lr: 0.00035203658778440027
# Finish one epoch train: epoch 261, loss: 0.1020, time(s): 28.35
# 262
# train: epoch 262, iter:0, loss: 0.1028, lr: 0.0003373247294785801
# Finish one epoch train: epoch 262, loss: 0.1149, time(s): 30.68
# 263
# train: epoch 263, iter:0, loss: 0.0850, lr: 0.0003227783464210839
# Finish one epoch train: epoch 263, loss: 0.1109, time(s): 27.31
# 264
# train: epoch 264, iter:0, loss: 0.0968, lr: 0.0003084117941357824
# Finish one epoch train: epoch 264, loss: 0.1172, time(s): 27.27
# 265
# train: epoch 265, iter:0, loss: 0.0950, lr: 0.00029423925067528794
# Finish one epoch train: epoch 265, loss: 0.1065, time(s): 26.78
# 266
# train: epoch 266, iter:0, loss: 0.1057, lr: 0.00028027470262892337
# train: epoch 285, iter:0, loss: 0.1065, lr: 7.122819337828722e-05
# Finish one epoch train: epoch 285, loss: 0.0972, time(s): 27.82
# 286
# train: epoch 286, iter:0, loss: 0.1013, lr: 6.395177052675766e-05
# Finish one epoch train: epoch 286, loss: 0.0967, time(s): 28.54
# 287
# train: epoch 287, iter:0, loss: 0.0979, lr: 5.711060902932015e-05
# Finish one epoch train: epoch 287, loss: 0.1061, time(s): 26.68
# 288
# train: epoch 288, iter:0, loss: 0.1219, lr: 5.0711460286429186e-05
# Finish one epoch train: epoch 288, loss: 0.0947, time(s): 27.38
# 289
# train: epoch 289, iter:0, loss: 0.0742, lr: 4.476063948531545e-05
# Finish one epoch train: epoch 289, loss: 0.0896, time(s): 27.73
# 290
# train: epoch 290, iter:0, loss: 0.0894, lr: 3.926401936765834e-05
# Finish one epoch train: epoch 290, loss: 0.0949, time(s): 29.09
# 291
# train: epoch 291, iter:0, loss: 0.0990, lr: 3.4227024433899005e-05
# Finish one epoch train: epoch 291, loss: 0.0996, time(s): 28.81
# 292
# train: epoch 292, iter:0, loss: 0.1120, lr: 2.9654625589913197e-05
# Finish one epoch train: epoch 292, loss: 0.0897, time(s): 21.43
# 293
# train: epoch 293, iter:0, loss: 0.1260, lr: 2.5551335241327638e-05
# Finish one epoch train: epoch 293, loss: 0.0922, time(s): 27.54
# 294
# train: epoch 294, iter:0, loss: 0.1015, lr: 2.1921202840320104e-05
# Finish one epoch train: epoch 294, loss: 0.0917, time(s): 21.19
# 295
# train: epoch 295, iter:0, loss: 0.0877, lr: 1.876781088929901e-05
# Finish one epoch train: epoch 295, loss: 0.0956, time(s): 21.20
# 296
# train: epoch 296, iter:0, loss: 0.0991, lr: 1.6094271405406794e-05
# Finish one epoch train: epoch 296, loss: 0.0961, time(s): 28.73
# 297
# train: epoch 297, iter:0, loss: 0.0939, lr: 1.3903222849333446e-05
# Finish one epoch train: epoch 297, loss: 0.1006, time(s): 21.32
# 298
# train: epoch 298, iter:0, loss: 0.0819, lr: 1.2196827521475399e-05
# Finish one epoch train: epoch 298, loss: 0.0962, time(s): 21.61
# 299
# train: epoch 299, iter:0, loss: 0.1012, lr: 1.0976769428005577e-05
# Finish one epoch train: epoch 299, loss: 0.0946, time(s): 20.65
# 300
# train: epoch 300, iter:0, loss: 0.1605, lr: 1.0244252618962858e-05
# Finish one epoch train: epoch 300, loss: 0.1028, time(s): 21.04
# 100% 12/12 [40:14<00:00, 201.18s/it]
# val epoch: 300, mean_dice: 0.6943179035376003, mean_hd95: 41.128234242885604, time(s): 2414.21
# #----------Testing----------#
# 100% 12/12 [43:29<00:00, 217.48s/it]
# val epoch: 300, mean_dice: 0.6930600373270095, mean_hd95: 38.17725151015807, time(s): 2609.73
